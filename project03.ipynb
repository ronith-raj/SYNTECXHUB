# %% [markdown]
# <a href="https://colab.research.google.com/github/ronith-raj/SYNTECXHUB/blob/main/project03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Step 1: Upload Dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4e32e1ad-f683-48fd-9fa4-c28d737bd1f0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e32e1ad-f683-48fd-9fa4-c28d737bd1f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Step 2: Load Dataset
import pandas as pd

df = pd.read_csv('/content/StudentsPerformance.csv', encoding='latin1')

df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#Step 3: Check Missing Values
print("Missing Values:\n")
print(df.isnull().sum())
# Out:
# Missing Values:
#
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
#Step 4: Handle Missing Values
for col in df.columns:
    if df[col].dtype == 'object':  # categorical
        df[col] = df[col].fillna(df[col].mode()[0])
    else:  # numerical
        df[col] = df[col].fillna(df[col].mean())

# %%
#Step 5: Fix Data Types
print("\nData Types Before:\n", df.dtypes)

# Convert scores to numeric (safety step)
df['math score'] = pd.to_numeric(df['math score'], errors='coerce')
df['reading score'] = pd.to_numeric(df['reading score'], errors='coerce')
df['writing score'] = pd.to_numeric(df['writing score'], errors='coerce')

print("\nData Types After:\n", df.dtypes)
# Out:
# Data Types Before:
#  gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object
#
# Data Types After:
#  gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
#Step 6: Remove Duplicates
print("Before:", df.shape)

df = df.drop_duplicates()

print("After:", df.shape)
# Out:
# Before: (1000, 8)
# After: (1000, 8)

# %%
#Step 7: Standardize Column Names
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

print(df.columns)
# Out:
# Index(['gender', 'race/ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
#Step 8: Extra Cleaning
# Remove invalid scores (if any)
df = df[(df['math_score'] >= 0) & (df['math_score'] <= 100)]
df = df[(df['reading_score'] >= 0) & (df['reading_score'] <= 100)]
df = df[(df['writing_score'] >= 0) & (df['writing_score'] <= 100)]

# %%
#Step 9: Save Cleaned Dataset
df.to_csv('cleaned_students.csv', index=False)

# %%
#Step 10: Cleaning Log
print("Data Cleaning Summary:")
print("- Missing values handled (mean/mode)")
print("- Data types corrected")
print("- Duplicates removed")
print("- Column names standardized")
print("- Invalid values removed")
# Out:
# Data Cleaning Summary:
# - Missing values handled (mean/mode)
# - Data types corrected
# - Duplicates removed
# - Column names standardized
# - Invalid values removed
